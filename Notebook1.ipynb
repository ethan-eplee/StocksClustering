# %%
# Load libraries
import numpy as np
import pandas as pd
import pandas_datareader as dr
from pandas import read_csv, set_option
from pandas.plotting import scatter_matrix
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import StandardScaler

# Import Model Packages 
from sklearn.cluster import KMeans, AgglomerativeClustering,AffinityPropagation, DBSCAN
from scipy.cluster.hierarchy import fcluster
from scipy.cluster.hierarchy import dendrogram, linkage, cophenet
from scipy.spatial.distance import pdist
from sklearn.metrics import adjusted_mutual_info_score
from sklearn import cluster, covariance, manifold

# Other Helper Packages and functions
import matplotlib.ticker as ticker
from itertools import cycle

import yahoo_fin.stock_info as si
import yfinance as yf

import datetime
import warnings
warnings.filterwarnings("ignore")

# %matplotlib inline
# %load_ext autotime
# Out:
# time: 0 ns (started: 2022-10-15 22:29:43 +08:00)

# %%
# The dataset was obtained from Kaggle and imported
df = read_csv('./data/stockprices.csv')
# Out:
# time: 1.26 s (started: 2022-10-15 22:29:43 +08:00)

# %%
df.head()
# Out:
#                         Date Symbol  Adj Close      Close       High  \
# 0  2010-01-04 00:00:00-05:00    MMM  59.318886  83.019997  83.449997
# 1  2010-01-05 00:00:00-05:00    MMM  58.947342  82.500000  83.230003
# 2  2010-01-06 00:00:00-05:00    MMM  59.783295  83.669998  84.599998
# 3  2010-01-07 00:00:00-05:00    MMM  59.826176  83.730003  83.760002
# 4  2010-01-08 00:00:00-05:00    MMM  60.247749  84.320000  84.320000
#
#          Low       Open     Volume
# 0  82.669998  83.089996  3043700.0
# 1  81.699997  82.800003  2847000.0
# 2  83.510002  83.879997  5268500.0
# 3  82.120003  83.320000  4470100.0
# 4  83.300003  83.690002  3405800.0
# time: 16 ms (started: 2022-10-15 22:29:45 +08:00)

# %%
len(df)
# Out:
# 1619660
# time: 0 ns (started: 2022-10-15 22:29:45 +08:00)

# %%
# Transform table
pd.pivot_table(df, index='Date', columns='Symbol', values='Adj Close')
# Out:
# Symbol                              A        AAL         AAP        AAPL  \
# Date
# 2010-01-04 00:00:00-05:00   20.434929   4.496876   38.432693    6.572423
# 2010-01-05 00:00:00-05:00   20.212959   5.005957   38.204258    6.583786
# 2010-01-06 00:00:00-05:00   20.141132   4.798555   38.537392    6.479064
# 2010-01-07 00:00:00-05:00   20.115025   4.939965   38.527885    6.467087
# 2010-01-08 00:00:00-05:00   20.108498   4.845690   38.680153    6.510081
# ...                               ...        ...         ...         ...
# 2022-10-04 00:00:00-04:00  131.410004  12.950000  167.830002  146.100006
# 2022-10-05 00:00:00-04:00  132.639999  12.870000  167.639999  146.399994
# 2022-10-06 00:00:00-04:00  132.179993  12.730000  165.139999  145.429993
# 2022-10-07 00:00:00-04:00  127.440002  12.180000  161.320007  140.089996
# 2022-10-10 00:00:00-04:00  125.949997  12.050000  166.250000  140.419998
#
# Symbol                           ABBV         ABC        ABMD         ABT  \
# Date
# 2010-01-04 00:00:00-05:00         NaN   22.101795    8.740000   19.778837
# 2010-01-05 00:00:00-05:00         NaN   21.944103    8.530000   19.619041
# 2010-01-06 00:00:00-05:00         NaN   21.736616    8.400000   19.727999
# 2010-01-07 00:00:00-05:00         NaN   21.388039    8.400000   19.891426
# 2010-01-08 00:00:00-05:00         NaN   21.620419    8.230000   19.993120
# ...                               ...         ...         ...         ...
# 2022-10-04 00:00:00-04:00  141.990005  142.729996  264.010010  103.080002
# 2022-10-05 00:00:00-04:00  143.330002  142.449997  264.260010  103.379997
# 2022-10-06 00:00:00-04:00  140.289993  139.910004  267.209991  102.449997
# 2022-10-07 00:00:00-04:00  138.759995  137.350006  257.089996  101.790001
# 2022-10-10 00:00:00-04:00  138.309998  137.619995  247.029999  101.129997
#
# Symbol                            ACN        ADBE  ...       WYNN        XEL  \
# Date                                               ...
# 2010-01-04 00:00:00-05:00   32.970871   37.090000  ...  41.963718  13.932555
# 2010-01-05 00:00:00-05:00   33.174648   37.700001  ...  44.515926  13.767320
# 2010-01-06 00:00:00-05:00   33.527321   37.619999  ...  43.932011  13.793758
# 2010-01-07 00:00:00-05:00   33.495968   36.889999  ...  44.870213  13.734278
# 2010-01-08 00:00:00-05:00   33.362751   36.689999  ...  44.548744  13.740885
# ...                               ...         ...  ...        ...        ...
# 2022-10-04 00:00:00-04:00  274.309998  294.970001  ...  70.739998  66.470001
# 2022-10-05 00:00:00-04:00  274.339996  297.380005  ...  72.180000  64.330002
# 2022-10-06 00:00:00-04:00  269.470001  298.410004  ...  74.169998  61.820000
# 2022-10-07 00:00:00-04:00  259.709991  288.769989  ...  73.089996  59.860001
# 2022-10-10 00:00:00-04:00  257.850006  285.720001  ...  64.139999  60.209999
#
# Symbol                            XOM       XRAY        XYL         YUM  \
# Date
# 2010-01-04 00:00:00-05:00   43.185623  32.782581        NaN   19.900911
# 2010-01-05 00:00:00-05:00   43.354244  32.392876        NaN   19.832848
# 2010-01-06 00:00:00-05:00   43.728970  32.606281        NaN   19.691063
# 2010-01-07 00:00:00-05:00   43.591564  33.033108        NaN   19.685392
# 2010-01-08 00:00:00-05:00   43.416687  33.033108        NaN   19.691063
# ...                               ...        ...        ...         ...
# 2022-10-04 00:00:00-04:00   95.269997  29.930000  93.139999  111.410004
# 2022-10-05 00:00:00-04:00   99.120003  30.240000  92.660004  112.330002
# 2022-10-06 00:00:00-04:00  102.059998  29.420000  91.660004  110.120003
# 2022-10-07 00:00:00-04:00  101.029999  28.410000  89.269997  108.930000
# 2022-10-10 00:00:00-04:00   98.839996  28.080000  88.820000  107.790001
#
# Symbol                            ZBH        ZBRA       ZION         ZTS
# Date
# 2010-01-04 00:00:00-05:00   53.282867   28.670000  11.580979         NaN
# 2010-01-05 00:00:00-05:00   54.969589   28.620001  11.989312         NaN
# 2010-01-06 00:00:00-05:00   54.951843   28.400000  13.031859         NaN
# 2010-01-07 00:00:00-05:00   56.212440   27.690001  14.491426         NaN
# 2010-01-08 00:00:00-05:00   55.031742   27.600000  14.256856         NaN
# ...                               ...         ...        ...         ...
# 2022-10-04 00:00:00-04:00  111.690002  281.649994  54.520000  154.750000
# 2022-10-05 00:00:00-04:00  112.489998  281.880005  53.520000  154.589996
# 2022-10-06 00:00:00-04:00  110.599998  280.350006  52.410000  152.589996
# 2022-10-07 00:00:00-04:00  108.260002  266.679993  50.369999  147.369995
# 2022-10-10 00:00:00-04:00  106.940002  258.600006  49.950001  145.779999
#
# [3215 rows x 503 columns]
# time: 969 ms (started: 2022-10-15 22:29:45 +08:00)

# %% [markdown]
# ## Define Start and End Date

# %%
# Define start date and end date for the data
start_date = '2016-01-03'
end_date = '2019-12-31'

df_sp500 = df[(df.Date>=start_date) & (df.Date<=end_date)]
# Out:
# time: 109 ms (started: 2022-10-15 22:29:46 +08:00)

# %%
df_sp500.describe()
# Out:
#            Adj Close          Close           High            Low  \
# count  495242.000000  495242.000000  495242.000000  495242.000000
# mean       96.619521     102.483144     103.461797     101.440198
# std       159.954705     160.412801     162.142631     158.604534
# min         0.700000       0.700000       0.710000       0.650000
# 25%        40.326423      44.320800      44.779999      43.860001
# 50%        65.812489      72.839996      73.489998      72.133331
# 75%       110.881840     118.400002     119.419998     117.300003
# max      3892.889893    3892.889893    3946.500000    3815.500000
#
#                 Open        Volume
# count  495242.000000  4.952420e+05
# mean      102.463467  4.898221e+06
# std       160.343233  1.249021e+07
# min         0.700000  0.000000e+00
# 25%        44.320000  9.726000e+05
# 50%        72.824356  1.990700e+06
# 75%       118.379997  4.376375e+06
# max      3900.000000  5.334788e+08
# time: 78 ms (started: 2022-10-15 22:29:46 +08:00)

# %%
#Checking for any null values and removing the null values'''
print('Null Values =', df_sp500.isnull().any())
# Out:
# Null Values = Date         False
# Symbol       False
# Adj Close     True
# Close         True
# High          True
# Low           True
# Open          True
# Volume        True
# dtype: bool
# time: 32 ms (started: 2022-10-15 22:29:46 +08:00)

# %%
df_sp500.isnull().sum()
# Out:
# Date             0
# Symbol           0
# Adj Close    12285
# Close        12285
# High         12285
# Low          12285
# Open         12285
# Volume       12285
# dtype: int64
# time: 31 ms (started: 2022-10-15 22:29:46 +08:00)

# %%
ddf
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_21004/1394284842.py in <module>
# ----> 1 ddf
#
# NameError: name 'ddf' is not defined
# time: 281 ms (started: 2022-10-15 22:29:46 +08:00)
